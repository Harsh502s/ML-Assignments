# %% [markdown]
# # Importing the Libraries

# %%
import warnings as w
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
w.filterwarnings('ignore')

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_csv(r"C:\Users\ds12\Data Sets\MLK\AB_NYC_2019.csv")

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ## Printing the data statistics.

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ## Printing the sturcutre of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ## Checking the no of null values in dataset

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Cleaning the Data

# %%
df.id = df.id.astype(str)

# %%
df.host_id = df.host_id.astype(str)

# %%
df.room_type = df.room_type.astype("category")

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
m1 = df["reviews_per_month"].median()

# %%
df["reviews_per_month"].replace(np.NaN, m1, inplace=True)

# %%
m2 = list(df["last_review"].mode())[0]

# %%
m2
# Out:
# '2019-06-23'

# %%
df["last_review"].replace(np.NaN, m2, inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.drop(["id", "name", "host_name", "neighbourhood"], axis=1, inplace=True)

# %%
neighbours = pd.get_dummies(df["neighbourhood_group"], drop_first=True)

# %%
roomtype = pd.get_dummies(df["room_type"], drop_first=True)

# %%
df = pd.concat([df, neighbours, roomtype], axis=1)

# %%
df.drop(["neighbourhood_group", "room_type"], axis=1, inplace=True)

# %%
df.last_review = pd.to_datetime(df["last_review"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48858 non-null  object
#  1   latitude                        48858 non-null  float64
#  2   longitude                       48858 non-null  float64
#  3   price                           48858 non-null  int64
#  4   minimum_nights                  48858 non-null  int64
#  5   number_of_reviews               48858 non-null  int64
#  6   last_review                     48858 non-null  datetime64[ns]
#  7   reviews_per_month               48858 non-null  float64
#  8   calculated_host_listings_count  48858 non-null  int64
#  9   availability_365                48858 non-null  int64
#  10  Brooklyn                        48858 non-null  uint8
#  11  Manhattan                       48858 non-null  uint8
# ...

# %%
df.head()
# Out:
#         host_id  latitude  longitude  price  minimum_nights  \
# 0          2787  40.64749  -73.97237    149               1
# 1          2845  40.75362  -73.98377    225               1
# 2          4632  40.80902  -73.94190    150               3
# 3          4869  40.68514  -73.95976     89               1
# 4          7192  40.79851  -73.94399     80              10
# ...         ...       ...        ...    ...             ...
# 48890   8232441  40.67853  -73.94995     70               2
# 48891   6570630  40.70184  -73.93317     40               4
# 48892  23492952  40.81475  -73.94867    115              10
# 48893  30985759  40.75751  -73.99112     55               1
# 48894  68119814  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      9  2018-10-19               0.21
# 1                     45  2019-05-21               0.38
# 2                      0  2019-06-23               0.72
# ...

# %% [markdown]
# ## Checking the host_ID's which have most listing.

# %%
m3 = df[["host_id", "calculated_host_listings_count"]].groupby("host_id").sum()

# %%
m3 = m3.sort_values(by="calculated_host_listings_count", ascending=False)

# %%
m3.reset_index(inplace=True)

# %%
m3.columns = ["host_id", "count"]

# %% [markdown]
# plt.figure(figsize=(10,10))
# sns.catplot(x='host_id',y='count',data=m3,kind='bar')

# %%
m3 = m3.iloc[:15, :]

# %% [markdown]
# ## Ploting the top 500 host_ID's which have most no of listings.

# %%
plt.figure(figsize=(10, 10))
plt.bar(m3["host_id"], m3["count"])
plt.xticks(rotation=90)

# %% [markdown]
# ## These are the top 15 host_ID's which have the highest no of calculated host listings.
